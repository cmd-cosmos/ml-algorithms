# %% [markdown]
# ### Selected Filters for different features of the image
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Example of a Valid Convolution
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# - to solve this, we add a padding of pixels around the grid with a -1 value
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### Strides
#  - stride of 2 ===> move 2 pixels at a time
#  - default stride is (1,1) on tensoflow
#
#  ![image.png](attachment:image.png)
