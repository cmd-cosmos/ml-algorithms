# %%
# 1 - handling imabalance using under sampling from majority class
# eg) if binary classification data with 90000 yes and 1000 no's then use 1000 yes samples and 1000 no samples 
# not a good idea

# %%
# 2 - over sampling the minority class by duplication
# duplicate the 1000 no's 90 times to get 90,000 (no) samples.
# this is also not a good idea

# %%
# 3 - over sampling the minority class using SMOTE
# - Use KNN to generate synthetic examples
# - SMOTE ---> Synthetic Minority Over-Sampling Technique
# - Use python imblearn lib

# %%
# 4 - Ensemble method
# - 9 batches of 1000 yes samples with the 1000 no samples per batch 
# - Majority vote to decide

# %%
# 5 - Focal loss
# - penalize majority samples during loss calc. and give more weight to minority class samples

# %%
### Some cases where there might be unbalanced data
# - customer churn rate
# - device failure
# - cancer prediction
