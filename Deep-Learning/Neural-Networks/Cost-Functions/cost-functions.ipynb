# %% [markdown]
# # Loss/Cost Functions:
# - individual errors are called training loss.
# - and the mean absolute error is the cost function.
# - 1 epoch ---> 1 pass through all samples in the dataset. 1 learning cycle on the complete dataset.
# - losses are used to train Neural Networks
# - helps compute best weights that will reduce the gap between predictions and truth thus reduce forward pass errors..
#
# # Sample Log Reg Neuron for Insurance Prediction
# ![image.png](attachment:image.png)

# %% [markdown]
# # mean absolute error
#
# - compare absolute distance error between predicted val and truth, then take average.
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # mean squared error
#
# - same as absolute error but each distance/gap is squared for mathematical simplicaity, simply allows for gradient descent to converge faster.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # log loss/binary crossentropy
#
# - loss function used for the same loss function used in binary classification to measure the difference between predicted probabilities and actual labels.
# - we use log loss for logistic regression problems for neural nets
# -  penalizes confident but incorrect predictions.
#
#
# ![image.png](attachment:image.png)

# %%
import numpy as np
