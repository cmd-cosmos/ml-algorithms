# %%
### Reference: https://medium.com/accredian/gradient-descent-from-the-ground-up-building-your-own-algorithm-from-scratch-a7f608559147

import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import math
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression

# %%
x,y = make_regression(n_samples=100, 
                      n_features=1,
                      n_informative=1,
                      n_targets=1,
                      noise=15,
                      random_state=42)

plt.scatter(x,y)

# %%
model = LinearRegression()

model.fit(x, y)
# Out:
# LinearRegression()

# %%
print(model.intercept_)
print(model.coef_)
# Out:
# 1.7476729807904583
# [45.78520483]

# %%
class GradientDescent:
    def __init__(self, epochs, alpha) -> None:
        self.epochs = epochs
        self.alpha = alpha
        self.m = 1 # slope
        self.b = 0 # intercept

    def fit(self, x, y):
        for i in range(self.epochs):
            loss_b = -2 * np.sum(y - self.m*x.ravel() - self.b)
            loss_m = -2 * np.sum((y - self.m*x.ravel() - self.b)*x.ravel())
            self.b = self.b - (self.alpha*loss_b)
            self.m = self.m - (self.alpha*loss_m)
            print("{} --- {}, {}".format(i+1, self.m, self.b))

# %%
gd = GradientDescent(epochs=100, alpha=0.001)
gd.fit(x,y)
### custom implementation of grad descent does converge to the val obtained by the lin reg model
# Out:
# 1 --- 8.373918415248287, -0.5806229143368344
# 2 --- 14.515679873900055, -0.89197009641196
# 3 --- 19.634751286403414, -1.013487734442809
# 4 --- 23.904290862538968, -1.0043822971714607
# 5 --- 27.467576159612793, -0.9084225841827954
# 6 --- 30.4432688024636, -0.7576478600753243
# 7 --- 32.92973108090645, -0.5752250172302906
# 8 --- 35.00856897624922, -0.37764465330464875
# 9 --- 36.74754334318184, -0.1764043470324923
# 10 --- 38.20296444337964, 0.020705184353942918
# 11 --- 39.42166356396878, 0.2086208919825756
# 12 --- 40.44261807235895, 0.38426498997036695
# 13 --- 41.29829216821552, 0.5459847823834237
# 14 --- 42.01574415851873, 0.6931323712896782
# 15 --- 42.61754179232681, 0.8257514205327717
# 16 --- 43.12251963739875, 0.9443455776166416
# 17 --- 43.546406330611525, 1.0497089413981167
# 18 --- 43.902344521665796, 1.1428034637952658
# 19 --- 44.20132223997046, 1.224671670022693
# 20 --- 44.452531074279534, 1.296375793969509
# 21 --- 44.66366382335968, 1.3589565256432874
# 22 --- 44.841162040216716, 1.4134061911222728
# 23 --- 44.99042206030914, 1.460652437838314
# 24 --- 45.11596660122876, 1.5015494618657015
# 25 --- 45.22158778707906, 1.53687455375808
# 26 --- 45.31046643611932, 1.5673283057347003
# 27 --- 45.38527161522814, 1.5935372549507012
# 28 --- 45.448243776858945, 1.6160580657902004
# 29 --- 45.50126422691353, 1.6353826023974272
# 30 --- 45.54591320372671, 1.6519434295009756
# 31 --- 45.583518461477404, 1.6661194193332662
# 32 --- 45.61519593137909, 1.678241246209722
# 33 --- 45.641883769137195, 1.6885966266967158
# 34 --- 45.66437087770586, 1.6974352188879025
# 35 --- 45.683320812388125, 1.7049731342230756
# 36 --- 45.69929182427537, 1.711397043435534
# 37 --- 45.71275367255182, 1.7168678775982507
# 38 --- 45.72410173188203, 1.7215241381406632
# 39 --- 45.733668834319104, 1.7254848378627181
# 40 --- 45.74173521291864, 1.7288520996942907
# 41 --- 45.748536854044225, 1.7317134422246574
# 42 --- 45.75427251515882, 1.734143781597642
# 43 --- 45.75910962302148, 1.7362071787823703
# 44 --- 45.76318923225069, 1.7379583598913124
# 45 --- 45.76663019501343, 1.7394440354206226
# 46 --- 45.769532668191985, 1.7407040422439495
# 47 --- 45.771981063968965, 1.7417723300488956
# 48 --- 45.77404653269233, 1.7426778117677808
# 49 --- 45.77578905258539, 1.7434450954896306
# 50 --- 45.777259188891975, 1.7440951133915872
# 51 --- 45.778499575013775, 1.744645661420259
# 52 --- 45.77954615978558, 1.7451118617989911
# 53 --- 45.780429257980785, 1.7455065589387189
# 54 --- 45.781174435221665, 1.7458406579849188
# 55 --- 45.78180325350274, 1.7461234140341402
# 56 --- 45.78233389936568, 1.7463626789912297
# 57 --- 45.782781713262686, 1.7465651121018686
# 58 --- 45.783159635703306, 1.7467363593731087
# 59 --- 45.783478583307726, 1.7468812063759613
# 60 --- 45.7837477658114, 1.7470037082978336
# 61 --- 45.78397495331876, 1.7471073005684414
# 62 --- 45.78416670163449, 1.7471948929112147
# 63 --- 45.784328542264475, 1.7472689492643942
# 64 --- 45.78446514263898, 1.7473315556640971
# 65 --- 45.78458044123489, 1.7473844778784928
# 66 --- 45.78467776153751, 1.7474292103215385
# 67 --- 45.78475990816204, 1.747467017550875
# 68 --- 45.78482924793249, 1.747498969462519
# 69 --- 45.78488777827619, 1.7475259711305695
# 70 --- 45.78493718492138, 1.747548788099481
# 71 --- 45.78497889057342, 1.7475680678162182
# 72 --- 45.78501409598206, 1.7475843577869519
# 73 --- 45.78504381459082, 1.747598120955355
# 74 --- 45.78506890177259, 1.7476097487248816
# 75 --- 45.78509007949835, 1.7476195719837946
# 76 --- 45.7851079571532, 1.7476278704375383
# 77 --- 45.78512304910188, 1.7476348805069724
# 78 --- 45.78513578951199, 1.7476408020117817
# 79 --- 45.78514654486334, 1.7476458038250733
# 80 --- 45.78515562450489, 1.7476500286568628
# 81 --- 45.78516328956434, 1.747653597100125
# 82 --- 45.78516976046748, 1.7476566110526808
# 83 --- 45.78517522328454, 1.7476591566108766
# 84 --- 45.78517983508648, 1.7476613065163384
# 85 --- 45.78518372846591, 1.7476631222246222
# 86 --- 45.785187015352875, 1.747664655654028
# 87 --- 45.78518979023564, 1.7476659506639058
# 88 --- 45.78519213287927, 1.7476670443041902
# 89 --- 45.785194110620274, 1.747667967871494
# 90 --- 45.78519578030362, 1.7476687478016402
# 91 --- 45.78519718991766, 1.7476694064239173
# 92 --- 45.78519837997431, 1.747669962598441
# 93 --- 45.78519938467405, 1.7476704322547076
# 94 --- 45.78520023288934, 1.7476708288466347
# 95 --- 45.7852009489948, 1.747671163737017
# 96 --- 45.78520155356799, 1.7476714465223346
# 97 --- 45.78520206398099, 1.7476716853071526
# 98 --- 45.785202494899806, 1.7476718869359296
# 99 --- 45.785202858705944, 1.7476720571888347
# 100 --- 45.785203165852295, 1.7476722009471588

# %%
### creating a dynamic plot to see grad descent find the best fit line

from matplotlib.animation import FuncAnimation
from matplotlib import animation

# init b and m to random vals
b     = -800   # intercept
m     = 500     # slope
alpha = 0.001  # learning rate
lst_b, lst_m, lst_cost = [], [], []
epochs = 50

for i in range(epochs):
    pd_b = 0
    pd_m = 0
    cost = 0
    for i in range(x.shape[0]):
        pd_b = pd_b - 2*(y[i] - (m*x[i]) - b)
        pd_m = pd_m - 2*(y[i] - (m*x[i]) - b)*x[i]
        cost = cost + (y[i] - m*x[i] - b)**2
    b = b - (alpha*pd_b)
    m = m - (alpha*pd_m)
    lst_b.append(b)
    lst_m.append(m)
    lst_cost.append(cost)

fig,ax = plt.subplots(figsize=(9,5))
x_i = np.arange(-5, 5, 0.1)
y_i = x_i*(-30) - 200
ax.scatter(x,y)
line, = ax.plot(x_i, x_i*50 - 4, 'r-', linewidth=2)

def update(i):
    label = 'epoch {0}'.format(i + 1)
    line.set_ydata(x_i*lst_m[i] + lst_b[i])
    ax.set_xlabel(label)

anim = FuncAnimation(fig, update, frames=epochs, interval=500, repeat=False)

# %%
## exporting the animation

f = r"animation.gif"
write = animation.PillowWriter(fps=2)
anim.save(f, writer=write)
